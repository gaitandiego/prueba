# %% [markdown]
# <a href="https://colab.research.google.com/github/gaitandiego/prueba/blob/main/Te_damos_la_bienvenida_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_str = 'Diego Gaitan'
for item in my_str:
    print(item)
# Out:
# D
# i
# e
# g
# o
#
# G
# a
# i
# t
# a
# n

# %%
my_dict = {"name": "jose", "surname": "garcia", "city": "Medellin"}

for value,index in my_dict.items():
    print(value,index)
# Out:
# name jose
# surname garcia
# city Medellin
